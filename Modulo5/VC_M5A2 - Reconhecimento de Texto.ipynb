# %% [markdown]
# # M5A2 - Reconhecimento de Texto

# %% [markdown]
# Na prática de hoje vamos utilizar um modelo na tarefa de reconhecimento de texto.
#
# Esse notebook está estruturado da seguinte forma.
#
# - Introdução
# - Utilizar Modelo
# - Próximos passos
# - Atividade Complementares

# %% [markdown]
# ## Introdução

# %% [markdown]
# Instalação para os que ainda não possuem a biblioteca instalada.

# %%
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (1.7.2)
# Requirement already satisfied: torch in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (2.12.1)
# Requirement already satisfied: torchvision>=0.5 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (0.27.1)
# Requirement already satisfied: opencv-python-headless in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (1.18.0)
# Requirement already satisfied: numpy in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (2.5.0)
# Requirement already satisfied: Pillow in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (12.2.0)
# Requirement already satisfied: scikit-image in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (0.26.0)
# Requirement already satisfied: python-bidi in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (0.6.10)
# Requirement already satisfied: PyYAML in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools<82 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from torch->easyocr) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from jinja2->torch->easyocr) (3.0.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from scikit-image->easyocr) (2026.6.1)
# Requirement already satisfied: packaging>=21 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from scikit-image->easyocr) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages (from scikit-image->easyocr) (0.5)

# %% [markdown]
# ## Introdução
#
# Importar as bibliotecas e visualizar imagens

# %%
import easyocr
from PIL import Image
import matplotlib.pyplot as plt

# %%
eng_image = Image.open("../assets/modulo5/images/eng.jpeg")
num_image = Image.open("../assets/modulo5/images/num.jpeg")

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))
axes[0].imshow(eng_image)
axes[1].imshow(num_image)

# %% [markdown]
# ## Carregar Modelo e Utilizar Modelo

# %%
reader = easyocr.Reader(["en"]) # Carrega o modelo de inglês para a memória.
# Out:
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
plt.imshow(eng_image)
result = reader.readtext("../assets/modulo5/images/eng.jpeg", detail=0)
print(result)
# Out:
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# ['PLEASE', 'Make', 'Sure', 'The', 'Door', 'Closes.']

# %%
plt.imshow(num_image)
result = reader.readtext("../assets/modulo5/images/num.jpeg", detail=0)
print(result)
# Out:
# ['19']
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)

# %% [markdown]
# ## Próximos Passos e Referências

# %% [markdown]
# Nas próximas práticas vamos continuar trabalhando com problemas reais que envolvem Visão Computacional.
#
# Uma lista não exaustiva de referências segue:
#
# - https://github.com/JaidedAI/EasyOCR
# - https://www.jaided.ai/easyocr/
# - https://huggingface.co
# - https://pytorch.org/
# - https://docs.pytorch.org/vision/main/models.html
# - https://opencv.org/
# - https://learnopencv.com/blogs/
# - https://pyimagesearch.com/

# %% [markdown]
# ## Atividades Complementares (Opcional)

# %% [markdown]
# - [ ] Tente alterar as imagens utilizadas nos testes.
# - [ ] Altere o parâmetro `detail` para `1` e tente desenhar as informações de bounding box na imagem.

# %% [markdown]
# ---
#
# ### Atividade 1 — Outras imagens
#
# Criei imagens simples com PIL contendo textos diferentes dos originais pra testar o OCR em condições mais controladas — fundo branco, texto preto, sem ruído.
#
# ### Atividade 2 — Bounding boxes com `detail=1`
#
# Com `detail=1`, o `readtext` retorna as coordenadas de cada detecção junto com o texto e a confiança. Usei OpenCV pra desenhar os retângulos direto na imagem.

# %%
import os
os.makedirs("../assets/modulo5/images", exist_ok=True)

from PIL import Image, ImageDraw

def criar_imagem(texto, caminho, tamanho=(400, 100)):
    img = Image.new("RGB", tamanho, color="white")
    draw = ImageDraw.Draw(img)
    draw.text((10, 35), texto, fill="black")
    img.save(caminho)

criar_imagem("Residencia em Visao Computacional", "../assets/modulo5/images/teste1.png")
criar_imagem("Python 3.10 | PyTorch", "../assets/modulo5/images/teste2.png")
criar_imagem("1234 5678 9000", "../assets/modulo5/images/teste3.png")

for caminho in ["../assets/modulo5/images/teste1.png", "../assets/modulo5/images/teste2.png", "../assets/modulo5/images/teste3.png"]:
    plt.figure(figsize=(6, 1.5))
    plt.imshow(Image.open(caminho))
    plt.axis("off")
    plt.show()
    resultado = reader.readtext(caminho, detail=0)
    print(f"Resultado: {resultado}\n")
# Out:
# Resultado: ['Residenciaem', 'Computacional', 'Vis 0']
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Resultado: ['Python 3.10', 'PyTorch']
# Resultado: ['12345878 9000']
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)

# %%
import cv2
import numpy as np

def mostrar_com_bbox(caminho_imagem, reader):
    img = np.array(Image.open(caminho_imagem).convert("RGB"))
    resultados = reader.readtext(caminho_imagem, detail=1)  # detail=1 retorna bbox + texto + confiança

    for (bbox, texto, confianca) in resultados:
        pontos = np.array(bbox, dtype=np.int32)
        cv2.polylines(img, [pontos], isClosed=True, color=(0, 200, 0), thickness=2)
        cv2.putText(
            img, f"{texto} ({confianca:.2f})",
            tuple(pontos[0]),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 50, 50), 1
        )

    plt.figure(figsize=(8, 5))
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Bounding boxes: {caminho_imagem}")
    plt.show()

mostrar_com_bbox("../assets/modulo5/images/eng.jpeg", reader)
mostrar_com_bbox("../assets/modulo5/images/num.jpeg", reader)
# Out:
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# /Users/larry/Documents/Dev/Residencia/Jupyter Notebooks/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
